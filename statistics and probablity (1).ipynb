# %%
import numpy as np
score =(13,16,55,75)
print(np.median(score))
# Out:
# 35.5

# %%
import numpy as np
score =(15,56,90,99)
print(np.mean (score))
# Out:
# 65.0

# %%
from statistics import mode
votes=(1,2,2,3,4,4,5,6,6)
most_common=mode(votes)
print(most_common)
# Out:
# 2

# %%
import numpy as np
tight_data=(60,70,80)
spread_data=(56,66,76)
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 8.16496580927726

# %%
import random
#stimulating random predictions
for i in range (15):
    prediction= random.choice(["spam", "not spam"])
    print(f"email{i+1}: {prediction}")
# Out:
# email1: spam
# email2: spam
# email3: spam
# email4: spam
# email5: spam
# email6: spam
# email7: spam
# email8: not spam
# email9: spam
# email10: not spam
# email11: not spam
# email12: not spam
# email13: spam
# email14: not spam
# email15: spam

# %%
import random
# stimulating 10 dice rolls
sample=[random.randint(1,7) for _ in range(10)]
print("sample rolls:",sample)
print("sample mean:",sum(sample)/len(sample))
# Out:
# sample rolls: [4, 7, 1, 3, 1, 1, 2, 2, 2, 2]
# sample mean: 2.5
